# %%
from sklearn.datasets import load_boston
import pandas as pd
data = pd.read_csv(load_boston()['filename'], skiprows=1)

# %%
print(load_boston()['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ## Давайте пощупаем признаки

# %% [markdown]
# * CRIM - Y. Уровень преступности влияет на цену, однозначно
# * ZN - MB. Не до конца понимаю что значит этот признак, давайте его дескрайбнем

# %%
data.ZN.describe()
# Out:
# count    506.000000
# mean      11.363636
# std       23.322453
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: ZN, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
data.ZN.hist()

# %% [markdown]
# Большая часть не имеет этого признака. Попробуем модуль с ним и без него.

# %% [markdown]
# Далее укажу только признаки, которые вызывают сомнение (остальные будут включены в модель)

# %% [markdown]
# * CHAS - сомнительное название у переменной
# * RM
# * TAX
# * DIS - дистанция до центров занятости не кажется такой уже важной

# %%
import seaborn as sns
from pylab import rcParams
rcParams['figure.figsize'] = 12,12

# %% [markdown]
# ### Новые данные
# Графики внизу использовались также на следующих шагах для определения качества обработки признаков

# %%
sns.pairplot(data, height = 1)

# %% [markdown]
# Ну тут вот видно, что CHAS мало влияет на MEDV

# %% [markdown]
# ## Проверка качества данных

# %% [markdown]
# На гистограммах видно, что некоторые параметры имеют странное распределение. Посмотрим на их гистограммы поближе.

# %%
# А что там с черными?

data['B'].hist(bins = 50)

# %% [markdown]
# А нет, все нормально, это просто Америка :)

# %%
data['MEDV'].hist(bins = 50)

# %% [markdown]
# Странно, что на 50 такой всплеск, не вкладывается в нормальное распределение :)

# %%
data[data['MEDV'] == 50].describe().transpose()
# Out:
#          count        mean        std        min         25%         50%  \
# CRIM      16.0    2.703412   3.145228    0.01381    0.409202    1.491190
# ZN        16.0   19.062500  35.129226    0.00000    0.000000    0.000000
# INDUS     16.0    8.835904   6.946285    0.46000    3.647500    8.420894
# CHAS      16.0    0.375000   0.500000    0.00000    0.000000    0.000000
# NOX       16.0    0.566569   0.089586    0.40100    0.500000    0.605000
# RM        16.0    7.484000   1.062342    4.97000    6.932750    7.853000
# AGE       16.0   77.637500  26.934609   24.80000   63.650000   90.200000
# DIS       16.0    2.586087   1.592896    1.12960    1.350650    2.043300
# RAD       16.0    4.517276   1.384563    1.00000    4.341463    4.455285
# TAX       16.0  304.789634  70.746117  193.00000  261.750000  311.926829
# PTRATIO   16.0   15.734129   1.918424   13.00000   14.625000   14.700000
# B         16.0  381.743125  12.920621  347.88000  375.105000  386.495000
# ...

# %% [markdown]
# Очень большой разлет "соседних" данных при одной и то же оценки стоимости, т.е. криминалитет может в 900 раз отличаться, а ценник один.

# %%
data['TAX'].hist(bins = 50)

# %% [markdown]
# Есть два значения, которые сильно отличаются от остальных значений налога. ПРичем для 666 дьявольски много значений, глянем в данные

# %%
data[data['TAX'] == 666].describe().transpose()
# Out:
#          count        mean           std        min         25%        50%  \
# CRIM     132.0   12.759291  1.304117e+01    2.37857    5.686307    9.08499
# ZN       132.0    0.000000  0.000000e+00    0.00000    0.000000    0.00000
# INDUS    132.0   18.100000  4.636122e-14   18.10000   18.100000   18.10000
# CHAS     132.0    0.060606  2.395153e-01    0.00000    0.000000    0.00000
# NOX      132.0    0.672417  6.100432e-02    0.53200    0.614000    0.69300
# RM       132.0    6.022152  7.184487e-01    3.56100    5.713000    6.17600
# AGE      132.0   89.805303  1.262581e+01   40.30000   85.925000   94.40000
# DIS      132.0    2.061254  6.179013e-01    1.12960    1.589250    1.94340
# RAD      132.0   24.000000  0.000000e+00   24.00000   24.000000   24.00000
# TAX      132.0  666.000000  0.000000e+00  666.00000  666.000000  666.00000
# PTRATIO  132.0   20.200000  1.426499e-14   20.20000   20.200000   20.20000
# ...

# %% [markdown]
# Есть три параметра, которые не меняются в этих данных:
#     INDUS
#     RAD
#     PTRATIO
#
# И сюдя по всему они все наследуют какую-то ошибку, т.к. *во всех гистограммах у них в этом месте аномалия*

# %% [markdown]
# то же самое, только тут еще и косвенное подтверждение некорректности данных - строки идут подряд. Впрочем это касается и сток с TAX = 666 :) Давайте тогда подставим вместо этих данных их мат ожидание

# %% [markdown]
# ## Очистка данных

# %%
# Если я правильно понимаю методику, то для расчета значений, 
# которые мы будем использовать для подстановки вместо анамальных значений 
# не должны включать эти аманомальные значения
clean_data = data[(data['TAX'] != 711) & (data['TAX'] != 666)]
indus = clean_data['INDUS'].mean()
rad = clean_data['RAD'].mean()
tax = clean_data['TAX'].mean()
ptratio = clean_data['PTRATIO'].mean()

# %%
def fix_data(row):
    if (row['TAX'] == 711) or (row['TAX'] == 666) :
        row['INDUS'] = indus
        row['RAD'] = rad
        row['TAX'] = tax
        row['PTRATIO'] = ptratio
    
    return row

data = data.apply(fix_data, axis=1)

# %%
data.describe().transpose()
data['TAX'].hist(bins = 50)

# %%
def fix_medv(col):
    if col == 50: return medv
    else: return col

# MEDV тоже очистим от выбросов
medv = data[data['MEDV'] != 50]['MEDV'].mean()

data['MEDV'] = data['MEDV'].apply(fix_medv)

# %%
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %% [markdown]
# ## Поиск взаимосвязей

# %% [markdown]
# Определим корреляцию между параметрами

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# Ну вообщем-то и по цифрам CHAS самый бесполезный признак, но давайте попробуем постепенно удалять признаки, чтобы видеть динамику качества модели

# %% [markdown]
# ### Где сильная корреляция?

# %% [markdown]
# самая мощная коореляция MEDV с RM и LSTAT

# %% [markdown]
# ### Старые модели

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [-1.08011358e-01  4.64204584e-02  2.05586264e-02  2.68673382e+00
#  -1.77666112e+01  3.80986521e+00  6.92224640e-04 -1.47556685e+00
#   3.06049479e-01 -1.23345939e-02 -9.52747232e-01  9.31168327e-03
#  -5.24758378e-01]
# Bias: 36.459488385090005
# Error: 3.270862810900314

# %%
data.MEDV.mean()
# Out:
# 22.532806324110698

# %% [markdown]
# Ошибка порядка 15%, надо действовать дальше. Удаляем CHAS.

# %%
X = data[['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]

reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [-1.13139078e-01  4.70524578e-02  4.03114536e-02 -1.73669994e+01
#   3.85049169e+00  2.78375651e-03 -1.48537390e+00  3.28311011e-01
#  -1.37558288e-02 -9.90958031e-01  9.74145094e-03 -5.34157620e-01]
# Bias: 36.89195979693199
# Error: 3.291558836513229

# %% [markdown]
# Ошибка выросла :( Так.. может я данные не досмотрел, давайте глянем на характеристики данных.

# %%
data.describe().transpose()
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %% [markdown]
# Уберем количество комнат на жилище (RM):

# %%
X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [-1.15899170e-01  6.59172911e-02 -3.09783649e-02  2.93157697e+00
#  -2.10212006e+01  2.55921069e-02 -1.71841376e+00  4.01656981e-01
#  -1.48810823e-02 -1.14294300e+00  6.74718395e-03 -7.72070327e-01]
# Bias: 69.46716317922915
# Error: 3.605931085750778

# %% [markdown]
# Все параметры важны :) Ну а что если несколько убрать?

# %%
X = data[['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'RAD', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'RAD', 'PTRATIO', 'B', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [-8.36815811e-02 -6.33798693e-03  3.74309917e-02 -1.02847708e+01
#   4.39889993e+00  3.06285815e-02  1.37808848e-01 -1.12867804e+00
#   1.05442817e-02 -5.47605451e-01]
# Bias: 21.131813128969
# Error: 3.497375474396621

# %% [markdown]
# Вообщем модель лучше, чем при всех признаках получить не удается. Видимо потому что признаки слишком хорошо уже подобраны. Скучно.. давайте что ль график нарисуем. Сначала опять просчитаем модель для всех признаков.

# %%
X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [-1.08011358e-01  4.64204584e-02  2.05586264e-02  2.68673382e+00
#  -1.77666112e+01  3.80986521e+00  6.92224640e-04 -1.47556685e+00
#   3.06049479e-01 -1.23345939e-02 -9.52747232e-01  9.31168327e-03
#  -5.24758378e-01]
# Bias: 36.459488385090005
# Error: 3.270862810900314

# %%
data['PREDICTION'] = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']].apply(lambda x: sum(x * reg.coef_) + reg.intercept_, axis = 1)

# %%
rcParams['figure.figsize'] = 16,12
plt.plot(data['PREDICTION']) #СИНИЙ
plt.plot(data['MEDV']) #ОРАНЖЕВЫЙ

# %% [markdown]
# ### Новая модель

# %%
# Еще раз глянем на полную модель с очищенными данными

X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [-1.39253487e-01  2.45935603e-02 -4.50973974e-03 -3.29880286e-01
#  -1.44416320e+01  2.49043831e+00 -2.51997647e-02 -9.02261598e-01
#   5.23322412e-01 -1.51831911e-02 -7.20394302e-01  7.96611298e-03
#  -3.92022614e-01]
# Bias: 36.784968066082925
# Error: 3.0545852045136583

# %% [markdown]
# Круто! Результат улучшился! На сладкое сделаме модель на двух наиболее связанных параметрах

# %%
X = data[['RM', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)
print('Weights: {}'.format(reg.coef_))
print('Bias: {}'.format(reg.intercept_))

pred_values = reg.predict(data[['RM', 'LSTAT']])
print('Error: {}'.format(mean_absolute_error(pred_values, y)))
# Out:
# Weights: [ 3.05541744 -0.61928858]
# Bias: 10.269634398175754
# Error: 3.648495231755712

# %% [markdown]
# Нет, все-таки плохо получается, давайте опять график по первой новой модели сделаем)

# %%
X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
reg = LinearRegression().fit(X, y)

pred_values = reg.predict(data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']])

data['PREDICTION'] = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']].apply(lambda x: sum(x * reg.coef_) + reg.intercept_, axis = 1)

rcParams['figure.figsize'] = 16,12
plt.plot(data['PREDICTION']) #СИНИЙ
plt.plot(data['MEDV']) #ОРАНЖЕВЫЙ

# %% [markdown]
# Ну вот более гладкий график получился.
